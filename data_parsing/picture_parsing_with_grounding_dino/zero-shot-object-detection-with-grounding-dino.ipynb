# %%
# !nvidia-smi
# Out:
# Mon Dec 25 03:53:24 2023
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   35C    P8               9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %% [markdown]
# ## Install Grounding DINO 🦕

# %%
# %cd {HOME}
# !git clone https://github.com/IDEA-Research/GroundingDINO.git
# %cd {HOME}/GroundingDINO
# !pip install -q -e .
# !pip install -q roboflow
# Out:
# /content
# Cloning into 'GroundingDINO'...
# remote: Enumerating objects: 418, done.
# remote: Counting objects: 100% (181/181), done.
# remote: Compressing objects: 100% (59/59), done.
# remote: Total 418 (delta 138), reused 126 (delta 122), pack-reused 237
# Receiving objects: 100% (418/418), 12.85 MiB | 19.70 MiB/s, done.
# Resolving deltas: 100% (215/215), done.
# /content/GroundingDINO
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 254.7/254.7 kB 6.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 20.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.5/77.5 kB 11.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.0/69.0 kB 2.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.3/158.3 kB 11.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 25.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 9.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 MB 10.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 8.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 5.1 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# lida 0.0.10 requires fastapi, which is not installed.
# lida 0.0.10 requires kaleido, which is not installed.
# lida 0.0.10 requires python-multipart, which is not installed.
# lida 0.0.10 requires uvicorn, which is not installed.

# %%
import os

CONFIG_PATH = os.path.join(HOME, "GroundingDINO/groundingdino/config/GroundingDINO_SwinT_OGC.py")
print(CONFIG_PATH, "; exist:", os.path.isfile(CONFIG_PATH))
# Out:
# /content/GroundingDINO/groundingdino/config/GroundingDINO_SwinT_OGC.py ; exist: True

# %% [markdown]
# ## Download Grounding DINO Weights 🏋️

# %%
# %cd {HOME}
# !mkdir {HOME}/weights
# %cd {HOME}/weights

# !wget -q https://github.com/IDEA-Research/GroundingDINO/releases/download/v0.1.0-alpha/groundingdino_swint_ogc.pth
# Out:
# /content
# /content/weights

# %%
import os

WEIGHTS_NAME = "groundingdino_swint_ogc.pth"
WEIGHTS_PATH = os.path.join(HOME, "weights", WEIGHTS_NAME)
print(WEIGHTS_PATH, "; exist:", os.path.isfile(WEIGHTS_PATH))
# Out:
# /content/weights/groundingdino_swint_ogc.pth ; exist: True

# %% [markdown]
# ## Load Grounding DINO Model

# %%
# %cd {HOME}/GroundingDINO

from groundingdino.util.inference import load_model, load_image, predict, annotate

model = load_model(CONFIG_PATH, WEIGHTS_PATH)
# Out:
# /content/GroundingDINO
# /usr/local/lib/python3.10/dist-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3526.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# final text_encoder_type: bert-base-uncased
# tokenizer_config.json:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]

# %%
# Python code to install necessary libraries for the PDF extraction and conversion process
# !pip install rarfile PyMuPDF Pillow
# Out:
# Collecting rarfile
#   Downloading rarfile-4.1-py3-none-any.whl (28 kB)
# Collecting PyMuPDF
#   Downloading PyMuPDF-1.23.8-cp310-none-manylinux2014_x86_64.whl (4.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 17.4 MB/s eta 0:00:00
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (9.4.0)
# Collecting PyMuPDFb==1.23.7 (from PyMuPDF)
#   Downloading PyMuPDFb-1.23.7-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (30.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.6/30.6 MB 49.9 MB/s eta 0:00:00
# Installing collected packages: rarfile, PyMuPDFb, PyMuPDF
# Successfully installed PyMuPDF-1.23.8 PyMuPDFb-1.23.7 rarfile-4.1

# %%
import os
import rarfile
import fitz  # PyMuPDF
from PIL import Image

def extract_rar(rar_path, extract_path):
    """
    Extracts a RAR file to a specified directory.
    """
    with rarfile.RarFile(rar_path) as rf:
        rf.extractall(path=extract_path)
    print(f"Extracted RAR contents to {extract_path}")

def convert_pdf_to_images(pdf_path, output_dir, dpi=600):
    """
    Converts each page of a PDF to an image and saves it in a specified directory.
    """
    doc = fitz.open(pdf_path)
    for page_num in range(len(doc)):
        page = doc.load_page(page_num)  # load page
        pix = page.get_pixmap(dpi=dpi)  # render page to an image
        img = Image.frombytes("RGB", [pix.width, pix.height], pix.samples)
        img.save(os.path.join(output_dir, f"page_{page_num + 1}.png"))
    doc.close()


def process_rar_to_images(rar_path, output_base_path):
    """
    Extracts RAR and converts all contained PDFs to images, each in its own directory.
    """
    # Extract RAR
    extract_path = "/content/drive/MyDrive/pdf_image/extracted/100_PDF"
    extract_rar(rar_path, extract_path)

    # Process each PDF
    for item in os.listdir(extract_path):
        if item.lower().endswith('.pdf'):
            pdf_path = os.path.join(extract_path, item)
            pdf_name = os.path.splitext(item)[0]
            output_dir = os.path.join(output_base_path, pdf_name)
            os.makedirs(output_dir, exist_ok=True)
            convert_pdf_to_images(pdf_path, output_dir)
            print(f"Converted {item} to images in {output_dir}")

    print("Completed processing all PDFs in the RAR file.")

# Example usage
rar_path = "/content/drive/MyDrive/pdf.rar" # Replace with your RAR file path
output_base_path = "/content/drive/MyDrive/pdf_image_4"  # Base path for output, change if needed

# Uncomment the line below to run the function
process_rar_to_images(rar_path, output_base_path)
# Out:
# Extracted RAR contents to /content/drive/MyDrive/pdf_image/extracted/100_PDF
# Converted elsevier_354c8aacec9691b4a9c1334bccc7818d224b2971.pdf to images in /content/drive/MyDrive/pdf_image_4/elsevier_354c8aacec9691b4a9c1334bccc7818d224b2971
# Converted elsevier_0d8e1fc979302d36e57072865329cbb30781292d.pdf to images in /content/drive/MyDrive/pdf_image_4/elsevier_0d8e1fc979302d36e57072865329cbb30781292d
# Converted elsevier_060c68226fbc74c162409aeec9ed07224e9a1ca9.pdf to images in /content/drive/MyDrive/pdf_image_4/elsevier_060c68226fbc74c162409aeec9ed07224e9a1ca9
# Converted elsevier_05cbcb9ef5629bc25e84df43572f9d1eddb9a35f.pdf to images in /content/drive/MyDrive/pdf_image_4/elsevier_05cbcb9ef5629bc25e84df43572f9d1eddb9a35f
# Converted elsevier_36b9d6d65905af4c409014d17de90ed316495a9f.pdf to images in /content/drive/MyDrive/pdf_image_4/elsevier_36b9d6d65905af4c409014d17de90ed316495a9f
# Converted elsevier_219a105beec6e4543076e6e08395200ece078488.pdf to images in /content/drive/MyDrive/pdf_image_4/elsevier_219a105beec6e4543076e6e08395200ece078488
# Converted elsevier_22410424a4ce3e1769766b22214838677dcee740.pdf to images in /content/drive/MyDrive/pdf_image_4/elsevier_22410424a4ce3e1769766b22214838677dcee740
# Converted elsevier_0264117beec41f34315fbb0ed6ca69d3de5b0964.pdf to images in /content/drive/MyDrive/pdf_image_4/elsevier_0264117beec41f34315fbb0ed6ca69d3de5b0964
# Converted elsevier_2fc6d3f56ff87374fd11fe544755aeb59f340420.pdf to images in /content/drive/MyDrive/pdf_image_4/elsevier_2fc6d3f56ff87374fd11fe544755aeb59f340420
# Converted elsevier_3701bbdfdc7bd26ce596cea417c63d058f9d8967.pdf to images in /content/drive/MyDrive/pdf_image_4/elsevier_3701bbdfdc7bd26ce596cea417c63d058f9d8967
# Converted elsevier_3e28cb9ac8282bc18d8fb861625319677ddf4ba7.pdf to images in /content/drive/MyDrive/pdf_image_4/elsevier_3e28cb9ac8282bc18d8fb861625319677ddf4ba7
# Converted elsevier_40e6fb002ef91f3b0515125badc005979aa8c450.pdf to images in /content/drive/MyDrive/pdf_image_4/elsevier_40e6fb002ef91f3b0515125badc005979aa8c450
# Converted elsevier_425acf78d2a329aeae5bf8c9545e8f49f1ef29db.pdf to images in /content/drive/MyDrive/pdf_image_4/elsevier_425acf78d2a329aeae5bf8c9545e8f49f1ef29db
# Converted elsevier_3bb76d98fb7e5c07a1c12f852be3f67a0fedfb68.pdf to images in /content/drive/MyDrive/pdf_image_4/elsevier_3bb76d98fb7e5c07a1c12f852be3f67a0fedfb68
# Converted elsevier_44bd2abd435db2d313b4605d86854e998b451943.pdf to images in /content/drive/MyDrive/pdf_image_4/elsevier_44bd2abd435db2d313b4605d86854e998b451943
# Converted elsevier_422dfaabcc89dcd8e24b74699b921d5b7e89d0f8.pdf to images in /content/drive/MyDrive/pdf_image_4/elsevier_422dfaabcc89dcd8e24b74699b921d5b7e89d0f8
# Converted elsevier_54a38c9082806a51271d46529114eb0621cc564d.pdf to images in /content/drive/MyDrive/pdf_image_4/elsevier_54a38c9082806a51271d46529114eb0621cc564d
# Converted elsevier_4cbbd45c8e3ce27c28b944ec63c14bd75ea30bd7.pdf to images in /content/drive/MyDrive/pdf_image_4/elsevier_4cbbd45c8e3ce27c28b944ec63c14bd75ea30bd7
# Converted elsevier_58f2e50f577c81ae1a13282e7d44691287851495.pdf to images in /content/drive/MyDrive/pdf_image_4/elsevier_58f2e50f577c81ae1a13282e7d44691287851495
# Converted elsevier_4f2914bac14a2e3830ac1d21c804e6f4c82faf04.pdf to images in /content/drive/MyDrive/pdf_image_4/elsevier_4f2914bac14a2e3830ac1d21c804e6f4c82faf04
# Converted elsevier_5efe74fcb81833bce79a52771e1d28b55b996b59.pdf to images in /content/drive/MyDrive/pdf_image_4/elsevier_5efe74fcb81833bce79a52771e1d28b55b996b59
# Converted elsevier_5f3a03832eb09ca847231b17de235981e6259d3b.pdf to images in /content/drive/MyDrive/pdf_image_4/elsevier_5f3a03832eb09ca847231b17de235981e6259d3b
# Converted elsevier_60d3584a74de01f94794232aa7c98fae118253bf.pdf to images in /content/drive/MyDrive/pdf_image_4/elsevier_60d3584a74de01f94794232aa7c98fae118253bf
# Converted elsevier_6759588a629dae3c5c948898fdd72ca36fc3ea57.pdf to images in /content/drive/MyDrive/pdf_image_4/elsevier_6759588a629dae3c5c948898fdd72ca36fc3ea57
# Converted elsevier_5fd5c887791bd6aebd53107ff5a229f02401cacf.pdf to images in /content/drive/MyDrive/pdf_image_4/elsevier_5fd5c887791bd6aebd53107ff5a229f02401cacf
# Converted elsevier_6124b5bb70491b125ece3d285644b738833a5bd6.pdf to images in /content/drive/MyDrive/pdf_image_4/elsevier_6124b5bb70491b125ece3d285644b738833a5bd6
# Converted elsevier_61eb312ec016eef195f1e4699574c3ddd693973d.pdf to images in /content/drive/MyDrive/pdf_image_4/elsevier_61eb312ec016eef195f1e4699574c3ddd693973d
# Converted elsevier_72102f6a0f373d2560a46ec7abb2280f229da8b1.pdf to images in /content/drive/MyDrive/pdf_image_4/elsevier_72102f6a0f373d2560a46ec7abb2280f229da8b1
# Converted elsevier_68beeb8209eb83a1bca4499c6d7230f1c514d5ee.pdf to images in /content/drive/MyDrive/pdf_image_4/elsevier_68beeb8209eb83a1bca4499c6d7230f1c514d5ee
# Converted elsevier_6c240a8b5372d7f24ddf5dbf39a041792571ab8f.pdf to images in /content/drive/MyDrive/pdf_image_4/elsevier_6c240a8b5372d7f24ddf5dbf39a041792571ab8f
# Converted elsevier_7323717f2e6174c1b6fbcb323954ae41797b7ead.pdf to images in /content/drive/MyDrive/pdf_image_4/elsevier_7323717f2e6174c1b6fbcb323954ae41797b7ead
# Converted elsevier_8a046e168f49a94beba3927df9dec08052eef525.pdf to images in /content/drive/MyDrive/pdf_image_4/elsevier_8a046e168f49a94beba3927df9dec08052eef525
# Converted elsevier_85666ac12bfed00b216834d137ea4c2f95662d63.pdf to images in /content/drive/MyDrive/pdf_image_4/elsevier_85666ac12bfed00b216834d137ea4c2f95662d63
# Converted elsevier_8678e81e2795a84696446b14d873e8ec337d04ba.pdf to images in /content/drive/MyDrive/pdf_image_4/elsevier_8678e81e2795a84696446b14d873e8ec337d04ba
# Converted elsevier_8cc90681e59d01e391b1e63d5a955a60d9519883.pdf to images in /content/drive/MyDrive/pdf_image_4/elsevier_8cc90681e59d01e391b1e63d5a955a60d9519883
# Converted elsevier_8bcede89702d759d8691544c357ab146c47a7fe7.pdf to images in /content/drive/MyDrive/pdf_image_4/elsevier_8bcede89702d759d8691544c357ab146c47a7fe7
# Converted elsevier_8e3d5126a7cafa65fd40eeea53d306eb2f6154b3.pdf to images in /content/drive/MyDrive/pdf_image_4/elsevier_8e3d5126a7cafa65fd40eeea53d306eb2f6154b3
# Converted elsevier_957bf97344aff3715b53bcf6c364ddf46c5e6796.pdf to images in /content/drive/MyDrive/pdf_image_4/elsevier_957bf97344aff3715b53bcf6c364ddf46c5e6796
# Converted elsevier_a27d7e462a8471e4499851b1fa8c7249211d56d0.pdf to images in /content/drive/MyDrive/pdf_image_4/elsevier_a27d7e462a8471e4499851b1fa8c7249211d56d0
# Converted elsevier_945362638728c31a0831266a65f96dddf8dda268.pdf to images in /content/drive/MyDrive/pdf_image_4/elsevier_945362638728c31a0831266a65f96dddf8dda268
# Converted elsevier_a351f168fc8df44d333cdaa6c3a4f57707f5b3d1.pdf to images in /content/drive/MyDrive/pdf_image_4/elsevier_a351f168fc8df44d333cdaa6c3a4f57707f5b3d1
# Converted elsevier_a3affc37e80876bdfe85dae2ef254da64ceab64e.pdf to images in /content/drive/MyDrive/pdf_image_4/elsevier_a3affc37e80876bdfe85dae2ef254da64ceab64e
# Converted elsevier_a8bda85cdb1f57ced535b02591459742f79d2f7c.pdf to images in /content/drive/MyDrive/pdf_image_4/elsevier_a8bda85cdb1f57ced535b02591459742f79d2f7c
# Converted elsevier_a363ee2621aa6d569630922ec12c2efaee38772b.pdf to images in /content/drive/MyDrive/pdf_image_4/elsevier_a363ee2621aa6d569630922ec12c2efaee38772b
# Converted elsevier_aefff07753928b57ee07d5027493aa0105aabc1d.pdf to images in /content/drive/MyDrive/pdf_image_4/elsevier_aefff07753928b57ee07d5027493aa0105aabc1d
# Converted elsevier_ab28aadf915c219109a4809f565ac4c5164889b0.pdf to images in /content/drive/MyDrive/pdf_image_4/elsevier_ab28aadf915c219109a4809f565ac4c5164889b0
# Converted elsevier_ab214e9656361cd483d370c5151ae187a897e749.pdf to images in /content/drive/MyDrive/pdf_image_4/elsevier_ab214e9656361cd483d370c5151ae187a897e749
# Converted elsevier_b1bae03c11984c32fb4368af1392761b4fa5518c.pdf to images in /content/drive/MyDrive/pdf_image_4/elsevier_b1bae03c11984c32fb4368af1392761b4fa5518c
# Converted elsevier_b3037a42da0730677927535003b5f62d66d8d0fe.pdf to images in /content/drive/MyDrive/pdf_image_4/elsevier_b3037a42da0730677927535003b5f62d66d8d0fe
# Converted elsevier_b37bc9d97ea7510d40e7511fa7b4cee85d67a055.pdf to images in /content/drive/MyDrive/pdf_image_4/elsevier_b37bc9d97ea7510d40e7511fa7b4cee85d67a055
# Converted elsevier_b48330c3310571d595818663c8730f1ec12666e7.pdf to images in /content/drive/MyDrive/pdf_image_4/elsevier_b48330c3310571d595818663c8730f1ec12666e7
# Converted elsevier_b6572813703d92bc0868d380463f2a9352a2e869.pdf to images in /content/drive/MyDrive/pdf_image_4/elsevier_b6572813703d92bc0868d380463f2a9352a2e869
# Converted elsevier_b9349d7002042e20d17ed1c7cde276222f5d0d2f.pdf to images in /content/drive/MyDrive/pdf_image_4/elsevier_b9349d7002042e20d17ed1c7cde276222f5d0d2f
# Converted elsevier_c001ddab6adf32bfa308383ba7c883639881b6b8.pdf to images in /content/drive/MyDrive/pdf_image_4/elsevier_c001ddab6adf32bfa308383ba7c883639881b6b8
# Converted elsevier_be7db37a78e0a02bb68d36edb7921b892534146b.pdf to images in /content/drive/MyDrive/pdf_image_4/elsevier_be7db37a78e0a02bb68d36edb7921b892534146b
# Converted elsevier_c521500cf3b1d9e02cb90bbeb9b1f3b1c2c53dd6.pdf to images in /content/drive/MyDrive/pdf_image_4/elsevier_c521500cf3b1d9e02cb90bbeb9b1f3b1c2c53dd6
# Converted elsevier_c70472130e1def62bfa4eafc0ad94861252b6590.pdf to images in /content/drive/MyDrive/pdf_image_4/elsevier_c70472130e1def62bfa4eafc0ad94861252b6590
# Converted elsevier_c82c2144fe76370f97c137c486c254408af11a81.pdf to images in /content/drive/MyDrive/pdf_image_4/elsevier_c82c2144fe76370f97c137c486c254408af11a81
# Converted elsevier_caa064e2ef1a7e6f60031491146541384f3796e7.pdf to images in /content/drive/MyDrive/pdf_image_4/elsevier_caa064e2ef1a7e6f60031491146541384f3796e7
# Converted elsevier_c71606d3c7f29b6051afdfba17f24aad088167aa.pdf to images in /content/drive/MyDrive/pdf_image_4/elsevier_c71606d3c7f29b6051afdfba17f24aad088167aa
# Converted elsevier_cc74bdf9928fd4720576750e2d0e4e02b1d57f31.pdf to images in /content/drive/MyDrive/pdf_image_4/elsevier_cc74bdf9928fd4720576750e2d0e4e02b1d57f31
# Converted elsevier_d046cf0ba4694c9fb9cfc1a83c1af7a65a7668b5.pdf to images in /content/drive/MyDrive/pdf_image_4/elsevier_d046cf0ba4694c9fb9cfc1a83c1af7a65a7668b5
# Converted elsevier_d5ab94de9758dac9198804c8667aded9753a81be.pdf to images in /content/drive/MyDrive/pdf_image_4/elsevier_d5ab94de9758dac9198804c8667aded9753a81be
# Converted elsevier_d72d71beb2d6dec68407b7b41a08f41d8fb5c4b2.pdf to images in /content/drive/MyDrive/pdf_image_4/elsevier_d72d71beb2d6dec68407b7b41a08f41d8fb5c4b2
# Converted elsevier_e3299c82d205d42ee4f9264bfd9f1c83dca81d98.pdf to images in /content/drive/MyDrive/pdf_image_4/elsevier_e3299c82d205d42ee4f9264bfd9f1c83dca81d98
# Converted elsevier_de229c41656849b455843d8bc259447780d76b44.pdf to images in /content/drive/MyDrive/pdf_image_4/elsevier_de229c41656849b455843d8bc259447780d76b44
# Converted elsevier_e27056c18507e497525f73c792931b0a8e6f13b0.pdf to images in /content/drive/MyDrive/pdf_image_4/elsevier_e27056c18507e497525f73c792931b0a8e6f13b0
# Converted elsevier_e9cd30d9b6b53aabd66bb2371fd828f557141a2d.pdf to images in /content/drive/MyDrive/pdf_image_4/elsevier_e9cd30d9b6b53aabd66bb2371fd828f557141a2d
# Converted elsevier_eb55cddd10a2bd38bfb7ec564b49eeab95caae93.pdf to images in /content/drive/MyDrive/pdf_image_4/elsevier_eb55cddd10a2bd38bfb7ec564b49eeab95caae93
# Converted elsevier_ec84bea4b888119ac5d8821304ef2569818d4089.pdf to images in /content/drive/MyDrive/pdf_image_4/elsevier_ec84bea4b888119ac5d8821304ef2569818d4089
# Converted elsevier_ee376f178530cc0f76628f4cf6ef1e51f964dd2b.pdf to images in /content/drive/MyDrive/pdf_image_4/elsevier_ee376f178530cc0f76628f4cf6ef1e51f964dd2b
# Converted elsevier_f439618ce779f7311a69b5c84b4bcae95b02c1f0.pdf to images in /content/drive/MyDrive/pdf_image_4/elsevier_f439618ce779f7311a69b5c84b4bcae95b02c1f0
# Converted elsevier_f4a1f38beffc994915b74da6ce8ad00ead3f5ba9.pdf to images in /content/drive/MyDrive/pdf_image_4/elsevier_f4a1f38beffc994915b74da6ce8ad00ead3f5ba9
# Converted elsevier_f719b93e1dae47e26544beba4c1b44f67d39a0e3.pdf to images in /content/drive/MyDrive/pdf_image_4/elsevier_f719b93e1dae47e26544beba4c1b44f67d39a0e3
# Converted elsevier_fbe95ba0e5497beebc4b1946746cb7f0ca5fc8ab.pdf to images in /content/drive/MyDrive/pdf_image_4/elsevier_fbe95ba0e5497beebc4b1946746cb7f0ca5fc8ab
# Converted elsevier_fa41fad0c5a5fc8e71bbb0584f55961536b11338.pdf to images in /content/drive/MyDrive/pdf_image_4/elsevier_fa41fad0c5a5fc8e71bbb0584f55961536b11338
# Converted geoscienceworld_6b44ce63b2a3908759972e85d8ec77fb11ac86f0.pdf to images in /content/drive/MyDrive/pdf_image_4/geoscienceworld_6b44ce63b2a3908759972e85d8ec77fb11ac86f0
# Converted geoscienceworld_d2105a688f30c43e8cac188f1bc657d7e5152ec8.pdf to images in /content/drive/MyDrive/pdf_image_4/geoscienceworld_d2105a688f30c43e8cac188f1bc657d7e5152ec8
# Converted elsevier_f7ff8d818e611a4b8168c910ec2ae999f0a288e5.pdf to images in /content/drive/MyDrive/pdf_image_4/elsevier_f7ff8d818e611a4b8168c910ec2ae999f0a288e5
# Converted geoscienceworld_888cef0642d9725ed48b135b58799ebd949faa0f.pdf to images in /content/drive/MyDrive/pdf_image_4/geoscienceworld_888cef0642d9725ed48b135b58799ebd949faa0f
# Converted geoscienceworld_ea93c84c774d0c41cb4548da74d35dcef22fcc3b.pdf to images in /content/drive/MyDrive/pdf_image_4/geoscienceworld_ea93c84c774d0c41cb4548da74d35dcef22fcc3b
# Converted lyell_0b1f37d9cfbf21e0e4cad2597e88dfc7302141f8.pdf to images in /content/drive/MyDrive/pdf_image_4/lyell_0b1f37d9cfbf21e0e4cad2597e88dfc7302141f8
# Converted springer_001f619dd722b1f1daf60dbc3ddc4a90310bd8c2.pdf to images in /content/drive/MyDrive/pdf_image_4/springer_001f619dd722b1f1daf60dbc3ddc4a90310bd8c2
# Converted mdpi_72e068217c22f828d33548801861b4228e61e680.pdf to images in /content/drive/MyDrive/pdf_image_4/mdpi_72e068217c22f828d33548801861b4228e61e680
# Converted springer_02f4a3c0adda9d9b9b744d08775448ecbd589ee0.pdf to images in /content/drive/MyDrive/pdf_image_4/springer_02f4a3c0adda9d9b9b744d08775448ecbd589ee0
# Converted springer_0e156914f09988e2625d30c768941c345f8ad80e.pdf to images in /content/drive/MyDrive/pdf_image_4/springer_0e156914f09988e2625d30c768941c345f8ad80e
# Converted springer_163b64959d0fbae01e6b426da1c8123df6c162e5.pdf to images in /content/drive/MyDrive/pdf_image_4/springer_163b64959d0fbae01e6b426da1c8123df6c162e5
# Converted springer_46f523525281b7a7faa8a4f71586dd85cc350874.pdf to images in /content/drive/MyDrive/pdf_image_4/springer_46f523525281b7a7faa8a4f71586dd85cc350874
# Converted springer_4ddf3fb0bcaaf32599d82c24a361ca32c5a6a7da.pdf to images in /content/drive/MyDrive/pdf_image_4/springer_4ddf3fb0bcaaf32599d82c24a361ca32c5a6a7da
# Converted springer_617558aaf7be01b105339d9b5f9a1f6aa46415f9.pdf to images in /content/drive/MyDrive/pdf_image_4/springer_617558aaf7be01b105339d9b5f9a1f6aa46415f9
# Converted springer_64538216fc0d319dad3c1016c407d16dcbab8d09.pdf to images in /content/drive/MyDrive/pdf_image_4/springer_64538216fc0d319dad3c1016c407d16dcbab8d09
# Converted springer_6bc79ccceffabaedfe77cedf3b18d2b2572c964b.pdf to images in /content/drive/MyDrive/pdf_image_4/springer_6bc79ccceffabaedfe77cedf3b18d2b2572c964b
# Converted springer_8024fd9e4e48973ab69bb0b20fac444d2e98d740.pdf to images in /content/drive/MyDrive/pdf_image_4/springer_8024fd9e4e48973ab69bb0b20fac444d2e98d740
# Converted springer_8b7dcdec280dc33ddb3812787f40884ea426b566.pdf to images in /content/drive/MyDrive/pdf_image_4/springer_8b7dcdec280dc33ddb3812787f40884ea426b566
# Converted springer_95086bc8e77bf7b0fd539fb0651b185736cb0618.pdf to images in /content/drive/MyDrive/pdf_image_4/springer_95086bc8e77bf7b0fd539fb0651b185736cb0618
# Converted springer_994d6fc59adaf3b97c876fc648034f3e6d4c2312.pdf to images in /content/drive/MyDrive/pdf_image_4/springer_994d6fc59adaf3b97c876fc648034f3e6d4c2312
# Converted springer_aba2230bce9da7aee992bcc50dbfc2bad32427b6.pdf to images in /content/drive/MyDrive/pdf_image_4/springer_aba2230bce9da7aee992bcc50dbfc2bad32427b6
# Converted springer_ce7733588084c36d738d941462464cf7e233fa0f.pdf to images in /content/drive/MyDrive/pdf_image_4/springer_ce7733588084c36d738d941462464cf7e233fa0f
# Converted wiley_23e958a16eb6cbb75240a1e354166d1385966dce.pdf to images in /content/drive/MyDrive/pdf_image_4/wiley_23e958a16eb6cbb75240a1e354166d1385966dce
# Converted wiley_65393b12db878a6ac711867a4f95d76110d40cb8.pdf to images in /content/drive/MyDrive/pdf_image_4/wiley_65393b12db878a6ac711867a4f95d76110d40cb8
# Completed processing all PDFs in the RAR file.

# %%
# !apt-get install unrar
import os

# RAR文件路径
rar_file = '/content/drive/MyDrive/pdf.rar'

# 解压目标文件夹
destination_folder = '/content/GroundingDINO/pdfimg'

# 创建目标文件夹（如果不存在）
if not os.path.exists(destination_folder):
    os.makedirs(destination_folder)

# 解压RAR文件
os.system(f'unrar x {rar_file} {destination_folder}')
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# unrar is already the newest version (1:6.1.5-1).
# 0 upgraded, 0 newly installed, 0 to remove and 15 not upgraded.
# 0

# %%
import zipfile
import os

# 指定要打包的文件夹和输出的ZIP文件名
folder_path = '/content/GroundingDINO/pdfimg/100_PDF/annotated_images_6'
zip_file = 'pdf_image_dino_highres.zip'

# 创建一个ZipFile对象
with zipfile.ZipFile(zip_file, 'w') as zipf:
    # 遍历文件夹中的所有文件和子文件夹
    for root, dirs, files in os.walk(folder_path):
        for file in files:
            # 将每个文件添加到zip文件中
            zipf.write(os.path.join(root, file))

print("打包完成")
# Out:
# 打包完成

# %%
import torchvision.transforms.functional as TF
import os
import numpy as np
import torch
import matplotlib.pyplot as plt
from matplotlib.image import imread
from torchvision.ops import box_convert
TEXT_PROMPT = "graph"
BOX_TRESHOLD = 0.35
TEXT_TRESHOLD = 0.25
PDF_IMG_FOLDER = "/content/drive/MyDrive/pdf_image_4"
OUTPUT_FOLDER = "/content/GroundingDINO/pdfimg/100_PDF/annotated_images_6"

def get_files_in_directory(directory):
    files = []
    for filename in os.listdir(directory):
        filepath = os.path.join(directory, filename)
        if os.path.isfile(filepath):
            files.append(filepath)
    return files

def process_pdf(pdf_img_dir):
    base_name = os.path.splitext(os.path.basename(pdf_img_dir))[0]
    output_images_folder = os.path.join(OUTPUT_FOLDER, base_name)
    os.makedirs(output_images_folder, exist_ok=True)
    pages = get_files_in_directory(pdf_img_dir)
    for i, page in enumerate(pages):
        image_path = os.path.join(output_images_folder, f"{i}.jpg")
        image_source, image = load_image(page)
        boxes, logits, phrases = predict(
              model=model,
              image=image,
              caption=TEXT_PROMPT,
              box_threshold=BOX_TRESHOLD,
              text_threshold=TEXT_TRESHOLD
          )
        annotated_frame = annotate(image_source=image_source, boxes=boxes, logits=logits, phrases=phrases)
        boxes = box_convert(boxes=boxes, in_fmt="cxcywh", out_fmt="xyxy")
        crop_and_save_images(page, boxes, output_images_folder, i)


def crop_and_save_images(image_path, boxes, output_path, i):
    # 读取原始图像
    img = imread(image_path)
    img_height, img_width = img.shape[:2]

    # 确保输出路径存在
    if not os.path.exists(output_path):
        os.makedirs(output_path)

    # 遍历boxes数组
    for j, box in enumerate(boxes):
        # 计算裁剪坐标
        left = int(box[0].item() * img_width)
        top = int(box[1].item() * img_height)
        right = int(box[2].item() * img_width)
        bottom = int(box[3].item() * img_height)

        if (box[0].item() <= 0.1 and box[1].item() <= 0.1 and box[2].item() >= 0.9 and box[3].item() >= 0.9):
          continue

        # 裁剪图像
        cropped_img = img[top:bottom, left:right]

        # 保存裁剪后的图像
        try:
          plt.imsave(os.path.join(output_path, f"{i}_{j}.jpg"), cropped_img)
        except Exception as e:
          print(e)



for dir in os.listdir(PDF_IMG_FOLDER):
    process_pdf(os.path.join(PDF_IMG_FOLDER, dir))
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/modeling_utils.py:907: FutureWarning: The `device` argument is deprecated and will be removed in v5 of Transformers.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:61: UserWarning: None of the inputs have requires_grad=True. Gradients will be None
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/modeling_utils.py:907: FutureWarning: The `device` argument is deprecated and will be removed in v5 of Transformers.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:61: UserWarning: None of the inputs have requires_grad=True. Gradients will be None
#   warnings.warn(

# %%
import os
import cv2
from pdf2image import convert_from_path
from GroundingDINO.groundingdino.util.inference import load_model, load_image, predict, annotate, Model

TRANSFORMERS_OFFLINE=1
CONFIG_PATH = "GroundingDINO/groundingdino/config/GroundingDINO_SwinT_OGC.py"
CHECKPOINT_PATH = "./GroundingDINO/groundingdino_swint_ogc.pth"
DEVICE = "cuda"
TEXT_PROMPT = "Illustration picture in an academic paper"
BOX_TRESHOLD = 0.35
TEXT_TRESHOLD = 0.25
PDF_IMG_FOLDER = "./100_PDF/images"
OUTPUT_FOLDER = "./100_PDF/annotated_images"
model = load_model(CONFIG_PATH, CHECKPOINT_PATH)

def get_files_in_directory(directory):
    files = []
    for filename in os.listdir(directory):
        filepath = os.path.join(directory, filename)
        if os.path.isfile(filepath):
            files.append(filepath)
    return files

def process_pdf(pdf_img_dir):
    base_name = os.path.splitext(os.path.basename(pdf_img_dir))[0]
    output_images_folder = os.path.join(OUTPUT_FOLDER, base_name)
    os.makedirs(output_images_folder, exist_ok=True)
    pages = get_files_in_directory(pdf_img_dir)
    for i, page in enumerate(pages):
        image_path = os.path.join(output_images_folder, f"{i}.jpg")
        image_source, image = load_image(page)
        boxes, logits, phrases = predict(
            model=model, image=image, caption=TEXT_PROMPT,
            box_threshold=BOX_TRESHOLD, text_threshold=TEXT_TRESHOLD,
            device=DEVICE
        )
        annotated_frame = annotate(image_source=image_source, boxes=boxes, logits=logits, phrases=phrases)
        cv2.imwrite(image_path, annotated_frame)

for dir in os.listdir(PDF_IMG_FOLDER):
    process_pdf(os.path.join(PDF_IMG_FOLDER, dir))
