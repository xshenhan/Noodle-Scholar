# %%
sub = {
    "0": {
        "main_subject": "cs",
        "num_papers": 841177
    },
    "1": {
        "main_subject": "math",
        "num_papers": 841004
    },
    "2": {
        "main_subject": "cond-mat",
        "num_papers": 470362
    },
    "3": {
        "main_subject": "astro-ph",
        "num_papers": 398052
    },
    "4": {
        "main_subject": "physics",
        "num_papers": 295379
    },
    "5": {
        "main_subject": "hep-ph",
        "num_papers": 175652
    },
    "6": {
        "main_subject": "hep-th",
        "num_papers": 162079
    },
    "7": {
        "main_subject": "quant-ph",
        "num_papers": 141289
    },
    "8": {
        "main_subject": "stat",
        "num_papers": 134796
    },
    "9": {
        "main_subject": "gr-qc",
        "num_papers": 103494
    },
    "10": {
        "main_subject": "eess",
        "num_papers": 78483
    },
    "11": {
        "main_subject": "math-ph",
        "num_papers": 76640
    },
    "12": {
        "main_subject": "nucl-th",
        "num_papers": 55577
    },
    "13": {
        "main_subject": "hep-ex",
        "num_papers": 51928
    },
    "14": {
        "main_subject": "q-bio",
        "num_papers": 49847
    },
    "15": {
        "main_subject": "nlin",
        "num_papers": 44624
    },
    "16": {
        "main_subject": "hep-lat",
        "num_papers": 27204
    },
    "17": {
        "main_subject": "nucl-ex",
        "num_papers": 25030
    },
    "18": {
        "main_subject": "q-fin",
        "num_papers": 22121
    },
    "19": {
        "main_subject": "econ",
        "num_papers": 8892
    },
    "20": {
        "main_subject": "chao-dyn",
        "num_papers": 2398
    },
    "21": {
        "main_subject": "q-alg",
        "num_papers": 1578
    },
    "22": {
        "main_subject": "alg-geom",
        "num_papers": 1423
    },
    "23": {
        "main_subject": "solv-int",
        "num_papers": 1413
    },
    "24": {
        "main_subject": "cmp-lg",
        "num_papers": 894
    },
    "25": {
        "main_subject": "dg-ga",
        "num_papers": 732
    },
    "26": {
        "main_subject": "patt-sol",
        "num_papers": 650
    },
    "27": {
        "main_subject": "adap-org",
        "num_papers": 584
    },
    "28": {
        "main_subject": "funct-an",
        "num_papers": 427
    },
    "29": {
        "main_subject": "mtrl-th",
        "num_papers": 262
    },
    "30": {
        "main_subject": "chem-ph",
        "num_papers": 251
    },
    "31": {
        "main_subject": "comp-gas",
        "num_papers": 221
    },
    "32": {
        "main_subject": "supr-con",
        "num_papers": 175
    },
    "33": {
        "main_subject": "atom-ph",
        "num_papers": 123
    },
    "34": {
        "main_subject": "acc-phys",
        "num_papers": 49
    },
    "35": {
        "main_subject": "plasm-ph",
        "num_papers": 38
    },
    "36": {
        "main_subject": "ao-sci",
        "num_papers": 17
    },
    "37": {
        "main_subject": "bayes-an",
        "num_papers": 16
    }
}
subsub = {
    "0": {
        "sub_subject": "hep-ph",
        "num_papers": 175652
    },
    "1": {
        "sub_subject": "hep-th",
        "num_papers": 162079
    },
    "2": {
        "sub_subject": "cs.LG",
        "num_papers": 157532
    },
    "3": {
        "sub_subject": "quant-ph",
        "num_papers": 141289
    },
    "4": {
        "sub_subject": "cs.CV",
        "num_papers": 108977
    },
    "5": {
        "sub_subject": "astro-ph",
        "num_papers": 105380
    },
    "6": {
        "sub_subject": "gr-qc",
        "num_papers": 103494
    },
    "7": {
        "sub_subject": "cond-mat.mtrl-sci",
        "num_papers": 88039
    },
    "8": {
        "sub_subject": "cond-mat.mes-hall",
        "num_papers": 86893
    },
    "9": {
        "sub_subject": "math-ph",
        "num_papers": 76640
    },
    "10": {
        "sub_subject": "math.MP",
        "num_papers": 76640
    },
    "11": {
        "sub_subject": "cs.AI",
        "num_papers": 75694
    },
    "12": {
        "sub_subject": "cond-mat.str-el",
        "num_papers": 71240
    },
    "13": {
        "sub_subject": "cond-mat.stat-mech",
        "num_papers": 71163
    },
    "14": {
        "sub_subject": "astro-ph.CO",
        "num_papers": 64733
    },
    "15": {
        "sub_subject": "math.CO",
        "num_papers": 62691
    },
    "16": {
        "sub_subject": "stat.ML",
        "num_papers": 62126
    },
    "17": {
        "sub_subject": "astro-ph.GA",
        "num_papers": 60703
    },
    "18": {
        "sub_subject": "math.AP",
        "num_papers": 58766
    },
    "19": {
        "sub_subject": "astro-ph.SR",
        "num_papers": 57666
    },
    "20": {
        "sub_subject": "nucl-th",
        "num_papers": 55577
    },
    "21": {
        "sub_subject": "astro-ph.HE",
        "num_papers": 54703
    },
    "22": {
        "sub_subject": "math.PR",
        "num_papers": 53597
    },
    "23": {
        "sub_subject": "cs.CL",
        "num_papers": 53451
    },
    "24": {
        "sub_subject": "hep-ex",
        "num_papers": 51928
    },
    "25": {
        "sub_subject": "math.AG",
        "num_papers": 50490
    },
    "26": {
        "sub_subject": "math.OC",
        "num_papers": 44895
    },
    "27": {
        "sub_subject": "cs.IT",
        "num_papers": 44508
    },
    "28": {
        "sub_subject": "math.IT",
        "num_papers": 44508
    },
    "29": {
        "sub_subject": "physics.optics",
        "num_papers": 43762
    },
    "30": {
        "sub_subject": "cond-mat.supr-con",
        "num_papers": 41999
    },
    "31": {
        "sub_subject": "math.DG",
        "num_papers": 40499
    },
    "32": {
        "sub_subject": "math.NT",
        "num_papers": 39835
    },
    "33": {
        "sub_subject": "cond-mat.soft",
        "num_papers": 38305
    },
    "34": {
        "sub_subject": "math.NA",
        "num_papers": 35194
    },
    "35": {
        "sub_subject": "math.DS",
        "num_papers": 34801
    },
    "36": {
        "sub_subject": "math.FA",
        "num_papers": 29626
    },
    "37": {
        "sub_subject": "cs.CR",
        "num_papers": 29579
    },
    "38": {
        "sub_subject": "cs.SY",
        "num_papers": 28621
    },
    "39": {
        "sub_subject": "cs.RO",
        "num_papers": 28198
    },
    "40": {
        "sub_subject": "astro-ph.EP",
        "num_papers": 27487
    },
    "41": {
        "sub_subject": "astro-ph.IM",
        "num_papers": 27380
    },
    "42": {
        "sub_subject": "hep-lat",
        "num_papers": 27204
    },
    "43": {
        "sub_subject": "physics.flu-dyn",
        "num_papers": 26509
    },
    "44": {
        "sub_subject": "nucl-ex",
        "num_papers": 25030
    },
    "45": {
        "sub_subject": "math.RT",
        "num_papers": 25011
    },
    "46": {
        "sub_subject": "stat.ME",
        "num_papers": 24706
    },
    "47": {
        "sub_subject": "eess.SP",
        "num_papers": 24683
    },
    "48": {
        "sub_subject": "cond-mat.dis-nn",
        "num_papers": 22848
    },
    "49": {
        "sub_subject": "cs.DS",
        "num_papers": 22802
    },
    "50": {
        "sub_subject": "math.GT",
        "num_papers": 21988
    },
    "51": {
        "sub_subject": "math.ST",
        "num_papers": 21776
    },
    "52": {
        "sub_subject": "stat.TH",
        "num_papers": 21776
    },
    "53": {
        "sub_subject": "physics.comp-ph",
        "num_papers": 21469
    },
    "54": {
        "sub_subject": "math.CA",
        "num_papers": 21365
    },
    "55": {
        "sub_subject": "math.GR",
        "num_papers": 21221
    },
    "56": {
        "sub_subject": "cs.NA",
        "num_papers": 21218
    },
    "57": {
        "sub_subject": "physics.soc-ph",
        "num_papers": 21116
    },
    "58": {
        "sub_subject": "physics.chem-ph",
        "num_papers": 20801
    },
    "59": {
        "sub_subject": "cs.NI",
        "num_papers": 20763
    },
    "60": {
        "sub_subject": "eess.IV",
        "num_papers": 20617
    },
    "61": {
        "sub_subject": "physics.atom-ph",
        "num_papers": 20315
    },
    "62": {
        "sub_subject": "cond-mat.quant-gas",
        "num_papers": 20280
    },
    "63": {
        "sub_subject": "eess.SY",
        "num_papers": 20166
    },
    "64": {
        "sub_subject": "physics.ins-det",
        "num_papers": 20085
    },
    "65": {
        "sub_subject": "cs.DC",
        "num_papers": 19872
    },
    "66": {
        "sub_subject": "cs.SI",
        "num_papers": 18607
    },
    "67": {
        "sub_subject": "math.QA",
        "num_papers": 18442
    },
    "68": {
        "sub_subject": "stat.AP",
        "num_papers": 17224
    },
    "69": {
        "sub_subject": "cs.CY",
        "num_papers": 16622
    },
    "70": {
        "sub_subject": "math.RA",
        "num_papers": 16598
    },
    "71": {
        "sub_subject": "physics.app-ph",
        "num_papers": 16552
    },
    "72": {
        "sub_subject": "math.CV",
        "num_papers": 16325
    },
    "73": {
        "sub_subject": "physics.plasm-ph",
        "num_papers": 15710
    },
    "74": {
        "sub_subject": "cond-mat.other",
        "num_papers": 15380
    },
    "75": {
        "sub_subject": "cs.IR",
        "num_papers": 15293
    },
    "76": {
        "sub_subject": "nlin.CD",
        "num_papers": 15288
    },
    "77": {
        "sub_subject": "cs.LO",
        "num_papers": 15259
    },
    "78": {
        "sub_subject": "cs.HC",
        "num_papers": 14975
    },
    "79": {
        "sub_subject": "math.AT",
        "num_papers": 14962
    },
    "80": {
        "sub_subject": "cs.SE",
        "num_papers": 14783
    },
    "81": {
        "sub_subject": "physics.bio-ph",
        "num_papers": 14597
    },
    "82": {
        "sub_subject": "cond-mat",
        "num_papers": 14215
    },
    "83": {
        "sub_subject": "cs.NE",
        "num_papers": 13295
    },
    "84": {
        "sub_subject": "eess.AS",
        "num_papers": 13017
    },
    "85": {
        "sub_subject": "cs.DM",
        "num_papers": 12699
    },
    "86": {
        "sub_subject": "math.LO",
        "num_papers": 12595
    },
    "87": {
        "sub_subject": "cs.SD",
        "num_papers": 12529
    },
    "88": {
        "sub_subject": "math.AC",
        "num_papers": 12363
    },
    "89": {
        "sub_subject": "math.OA",
        "num_papers": 12155
    },
    "90": {
        "sub_subject": "nlin.SI",
        "num_papers": 11566
    },
    "91": {
        "sub_subject": "q-bio.PE",
        "num_papers": 10962
    },
    "92": {
        "sub_subject": "math.MG",
        "num_papers": 10674
    },
    "93": {
        "sub_subject": "cs.GT",
        "num_papers": 10554
    },
    "94": {
        "sub_subject": "cs.CC",
        "num_papers": 10222
    },
    "95": {
        "sub_subject": "physics.gen-ph",
        "num_papers": 10166
    },
    "96": {
        "sub_subject": "physics.data-an",
        "num_papers": 9980
    },
    "97": {
        "sub_subject": "q-bio.QM",
        "num_papers": 9746
    },
    "98": {
        "sub_subject": "nlin.PS",
        "num_papers": 9397
    },
    "99": {
        "sub_subject": "math.SP",
        "num_papers": 9291
    },
    "100": {
        "sub_subject": "q-bio.NC",
        "num_papers": 8914
    },
    "101": {
        "sub_subject": "math.SG",
        "num_papers": 8734
    },
    "102": {
        "sub_subject": "physics.class-ph",
        "num_papers": 8243
    },
    "103": {
        "sub_subject": "cs.DB",
        "num_papers": 8125
    },
    "104": {
        "sub_subject": "math.CT",
        "num_papers": 8074
    },
    "105": {
        "sub_subject": "stat.CO",
        "num_papers": 7710
    },
    "106": {
        "sub_subject": "physics.acc-ph",
        "num_papers": 7483
    },
    "107": {
        "sub_subject": "cs.PL",
        "num_papers": 7325
    },
    "108": {
        "sub_subject": "cs.MA",
        "num_papers": 6944
    },
    "109": {
        "sub_subject": "nlin.AO",
        "num_papers": 6907
    },
    "110": {
        "sub_subject": "physics.geo-ph",
        "num_papers": 6701
    },
    "111": {
        "sub_subject": "cs.CG",
        "num_papers": 6487
    },
    "112": {
        "sub_subject": "physics.med-ph",
        "num_papers": 6407
    },
    "113": {
        "sub_subject": "cs.CE",
        "num_papers": 6334
    },
    "114": {
        "sub_subject": "physics.space-ph",
        "num_papers": 6063
    },
    "115": {
        "sub_subject": "physics.ao-ph",
        "num_papers": 6015
    },
    "116": {
        "sub_subject": "cs.MM",
        "num_papers": 5793
    },
    "117": {
        "sub_subject": "math.KT",
        "num_papers": 5691
    },
    "118": {
        "sub_subject": "cs.GR",
        "num_papers": 5302
    },
    "119": {
        "sub_subject": "q-bio.BM",
        "num_papers": 5194
    },
    "120": {
        "sub_subject": "math.GN",
        "num_papers": 4918
    },
    "121": {
        "sub_subject": "physics.hist-ph",
        "num_papers": 4738
    },
    "122": {
        "sub_subject": "cs.FL",
        "num_papers": 4701
    },
    "123": {
        "sub_subject": "cs.DL",
        "num_papers": 4601
    },
    "124": {
        "sub_subject": "cs.AR",
        "num_papers": 4341
    },
    "125": {
        "sub_subject": "q-fin.EC",
        "num_papers": 4112
    },
    "126": {
        "sub_subject": "math.GM",
        "num_papers": 3799
    },
    "127": {
        "sub_subject": "cs.ET",
        "num_papers": 3751
    },
    "128": {
        "sub_subject": "cs.PF",
        "num_papers": 3676
    },
    "129": {
        "sub_subject": "physics.ed-ph",
        "num_papers": 3670
    },
    "130": {
        "sub_subject": "q-bio.MN",
        "num_papers": 3604
    },
    "131": {
        "sub_subject": "econ.GN",
        "num_papers": 3545
    },
    "132": {
        "sub_subject": "math.HO",
        "num_papers": 3480
    },
    "133": {
        "sub_subject": "q-fin.ST",
        "num_papers": 3413
    },
    "134": {
        "sub_subject": "econ.EM",
        "num_papers": 3208
    },
    "135": {
        "sub_subject": "q-bio.GN",
        "num_papers": 2982
    },
    "136": {
        "sub_subject": "physics.atm-clus",
        "num_papers": 2661
    },
    "137": {
        "sub_subject": "q-fin.GN",
        "num_papers": 2569
    },
    "138": {
        "sub_subject": "cs.SC",
        "num_papers": 2401
    },
    "139": {
        "sub_subject": "chao-dyn",
        "num_papers": 2398
    },
    "140": {
        "sub_subject": "q-fin.MF",
        "num_papers": 2358
    },
    "141": {
        "sub_subject": "physics.pop-ph",
        "num_papers": 2336
    },
    "142": {
        "sub_subject": "q-fin.CP",
        "num_papers": 2234
    },
    "143": {
        "sub_subject": "cs.OH",
        "num_papers": 2178
    },
    "144": {
        "sub_subject": "q-bio.TO",
        "num_papers": 2147
    },
    "145": {
        "sub_subject": "econ.TH",
        "num_papers": 2139
    },
    "146": {
        "sub_subject": "q-fin.RM",
        "num_papers": 2123
    },
    "147": {
        "sub_subject": "cs.MS",
        "num_papers": 2117
    },
    "148": {
        "sub_subject": "q-bio.CB",
        "num_papers": 2075
    },
    "149": {
        "sub_subject": "q-fin.PR",
        "num_papers": 1908
    },
    "150": {
        "sub_subject": "q-fin.PM",
        "num_papers": 1745
    },
    "151": {
        "sub_subject": "q-bio.SC",
        "num_papers": 1659
    },
    "152": {
        "sub_subject": "q-fin.TR",
        "num_papers": 1659
    },
    "153": {
        "sub_subject": "q-alg",
        "num_papers": 1578
    },
    "154": {
        "sub_subject": "nlin.CG",
        "num_papers": 1466
    },
    "155": {
        "sub_subject": "alg-geom",
        "num_papers": 1423
    },
    "156": {
        "sub_subject": "solv-int",
        "num_papers": 1413
    },
    "157": {
        "sub_subject": "q-bio",
        "num_papers": 1356
    },
    "158": {
        "sub_subject": "stat.OT",
        "num_papers": 1254
    },
    "159": {
        "sub_subject": "q-bio.OT",
        "num_papers": 1208
    },
    "160": {
        "sub_subject": "cmp-lg",
        "num_papers": 894
    },
    "161": {
        "sub_subject": "cs.OS",
        "num_papers": 838
    },
    "162": {
        "sub_subject": "dg-ga",
        "num_papers": 732
    },
    "163": {
        "sub_subject": "patt-sol",
        "num_papers": 650
    },
    "164": {
        "sub_subject": "adap-org",
        "num_papers": 584
    },
    "165": {
        "sub_subject": "funct-an",
        "num_papers": 427
    },
    "166": {
        "sub_subject": "mtrl-th",
        "num_papers": 262
    },
    "167": {
        "sub_subject": "chem-ph",
        "num_papers": 251
    },
    "168": {
        "sub_subject": "comp-gas",
        "num_papers": 221
    },
    "169": {
        "sub_subject": "cs.GL",
        "num_papers": 210
    },
    "170": {
        "sub_subject": "supr-con",
        "num_papers": 175
    },
    "171": {
        "sub_subject": "atom-ph",
        "num_papers": 123
    },
    "172": {
        "sub_subject": "acc-phys",
        "num_papers": 49
    },
    "173": {
        "sub_subject": "plasm-ph",
        "num_papers": 38
    },
    "174": {
        "sub_subject": "ao-sci",
        "num_papers": 17
    },
    "175": {
        "sub_subject": "bayes-an",
        "num_papers": 16
    }
}

# %%
keywords_sub = set()
keywords_subsub = set()
for i in range(38):
    keywords_sub.add(sub[str(i)]["main_subject"])

wrong = 0
for i in range(176):
    keywords_subsub.add(subsub[str(i)]["sub_subject"])
    if subsub[str(i)]["sub_subject"] in keywords_sub:
        print(f"{subsub[str(i)]['sub_subject']} wrongly in sub")
        wrong += 1
print(wrong)
print(len(keywords_sub))
print(len(keywords_subsub))
# Out:
# hep-ph wrongly in sub
# hep-th wrongly in sub
# quant-ph wrongly in sub
# astro-ph wrongly in sub
# gr-qc wrongly in sub
# math-ph wrongly in sub
# nucl-th wrongly in sub
# hep-ex wrongly in sub
# hep-lat wrongly in sub
# nucl-ex wrongly in sub
# cond-mat wrongly in sub
# chao-dyn wrongly in sub
# q-alg wrongly in sub
# alg-geom wrongly in sub
# solv-int wrongly in sub
# q-bio wrongly in sub
# cmp-lg wrongly in sub
# dg-ga wrongly in sub
# patt-sol wrongly in sub
# adap-org wrongly in sub
# funct-an wrongly in sub
# mtrl-th wrongly in sub
# chem-ph wrongly in sub
# comp-gas wrongly in sub
# supr-con wrongly in sub
# atom-ph wrongly in sub
# acc-phys wrongly in sub
# plasm-ph wrongly in sub
# ao-sci wrongly in sub
# bayes-an wrongly in sub
# 30
# 38
# 176
